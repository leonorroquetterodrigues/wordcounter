# %%
from wordcounter.lib import*

# %%
part_of_speech('1. What is the difference between a grid search and a random search. In a grid search, the data scientist specifies which hyperparameters value to test, and each possible combination is tested. In a random search, a defined number of random samples are made out of a hyperparameter space and tested for performance. 50 sample iterations has proven to be a good tradeoff between time and efficiency. Name a few potential causes for underfitting, as well as few approaches to combat it. Occurs when the model is unable to capture and learn a structure in the data. \
The model could be too simplistic, or the data not sufficiently informative. \
In that case, you could choose a more complex model or do some feature engineering.')
# Out:
#           word category
# 0         name     NOUN
# 1         well        X
# 2            a      DET
# 3            .        .
# 4         that      DET
# 5           do     VERB
# 6          you     PRON
# 7           to      PRT
# 8          and     CONJ
# 9         what     PRON
# 10     between      ADP
# 11        good      ADJ
# 12           ,        .
# 13        have     VERB
# 14         the      DET
# 15         too      ADV
# 16         not      ADV
# 17          it     PRON
# 18         out      PRT
# 19          in      ADP
# 20          or     CONJ
# 21          of      ADP
# 22        make     VERB
# 23         for      ADP
# 24        when      ADV
# 25        more      ADV
# 26       could     VERB
# 27          be     VERB
# 28      choose     VERB
# 29      number     NOUN
# 30        time     NOUN
# 31        case     NOUN
# 32       cause      ADP
# 33        some      DET
# 34        test     NOUN
# 35        each      DET
# 36       which      DET
# ...
